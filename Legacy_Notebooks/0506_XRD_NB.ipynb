# %% [markdown]
# # The jupyter notebook version of the script:
# - Add: Normalizing at the ITO peak

# %%
from plot_module.xrd_analyzer import XRDAnalyzer
from plot_module.colors import color


figColor = color.matlab(multiData=True)


folder = '/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/XRD/XRD_05062025/Results'

# %% [markdown]
# ### Print and find the peaks at the ITO

# %%
X20s = XRDAnalyzer()
X20s.import_xrd_data(pathName='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/XRD/XRD_05062025/Results/20S_IPA.txt')
X25s = XRDAnalyzer()
X25s.import_xrd_data(pathName='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/XRD/XRD_05062025/Results/25S_IPA.txt')
XCBs = XRDAnalyzer()
XCBs.import_xrd_data(pathName='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/XRD/XRD_05062025/Results/CB.txt')
XR5s = XRDAnalyzer()
XR5s.import_xrd_data(pathName='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/XRD/XRD_05062025/Results/R5.txt')

# %%
X20s.find_peaks_and_FWHM(log=True)
X25s.find_peaks_and_FWHM(log=True)
XCBs.find_peaks_and_FWHM(log=True)
XR5s.find_peaks_and_FWHM(log=True)

# %%
print(X20s.peakAngles)
print(X20s.peakHeights)
# Out:
# [12.62 13.9  19.76 19.82 24.32 28.14 30.26 31.48 34.66]
# [0.03298562 0.09303637 0.01973499 0.01973499 1.         0.05793628
#  0.03157598 0.02734705 0.02748802]

# %%
for i in range(0, len(X20s.peakAngles)):
    print("Peak Angle:", X20s.peakAngles[i])
    print("Peak Heights:", X20s.peakHeights[i])
# Out:
# Peak Angle: 12.62
# Peak Heights: 0.032985621652100366
# Peak Angle: 13.9
# Peak Heights: 0.09303636876233437
# Peak Angle: 19.76
# Peak Heights: 0.01973498731322244
# Peak Angle: 19.82
# Peak Heights: 0.01973498731322244
# Peak Angle: 24.32
# Peak Heights: 1.0
# Peak Angle: 28.14
# Peak Heights: 0.05793628418381731
# Peak Angle: 30.26
# Peak Heights: 0.03157597970115591
# Peak Angle: 31.48
# Peak Heights: 0.027347053848322526
# Peak Angle: 34.66
# Peak Heights: 0.02748801804341697

# %%
X20s.intensities = X20s.intensities / 0.027347053848322526

# %%
for i in range(0, len(X25s.peakAngles)):
    print("Peak Angle:", X25s.peakAngles[i])
    print("Peak Heights:", X25s.peakHeights[i])
# Out:
# Peak Angle: 6.66
# Peak Heights: 0.021672771672771672
# Peak Angle: 13.92
# Peak Heights: 0.3836996336996337
# Peak Angle: 13.96
# Peak Heights: 0.38431013431013433
# Peak Angle: 16.86
# Peak Heights: 0.019536019536019536
# Peak Angle: 18.9
# Peak Heights: 0.02564102564102564
# Peak Angle: 19.82
# Peak Heights: 0.10897435897435898
# Peak Angle: 21.28
# Peak Heights: 0.045177045177045176
# Peak Angle: 21.8
# Peak Heights: 0.03235653235653236
# Peak Angle: 22.0
# Peak Heights: 0.03388278388278388
# Peak Angle: 22.44
# Peak Heights: 0.033577533577533576
# Peak Angle: 23.28
# Peak Heights: 0.04120879120879121
# Peak Angle: 23.36
# Peak Heights: 0.04151404151404151
# Peak Angle: 23.94
# Peak Heights: 0.04242979242979243
# Peak Angle: 24.32
# Peak Heights: 1.0
# Peak Angle: 24.66
# Peak Heights: 0.0521978021978022
# Peak Angle: 25.22
# Peak Heights: 0.03815628815628816
# Peak Angle: 25.7
# Peak Heights: 0.03663003663003663
# Peak Angle: 25.94
# Peak Heights: 0.039987789987789985
# ...

# %%
X25s.intensities = X25s.intensities / 0.19322344322344323# 0.19322344322344323

# %%
for i in range(0, len(XCBs.peakAngles)):
    print("Peak Angle:", XCBs.peakAngles[i])
    print("Peak Heights:", XCBs.peakHeights[i])
# Out:
# Peak Angle: 5.02
# Peak Heights: 0.08209806157354618
# Peak Angle: 5.08
# Peak Heights: 0.07411630558722919
# Peak Angle: 5.16
# Peak Heights: 0.08665906499429875
# Peak Angle: 5.22
# Peak Heights: 0.08893956670467502
# Peak Angle: 5.28
# Peak Heights: 0.08551881413911061
# Peak Angle: 5.46
# Peak Heights: 0.09464082098061574
# Peak Angle: 5.54
# Peak Heights: 0.07525655644241733
# Peak Angle: 5.62
# Peak Heights: 0.07525655644241733
# Peak Angle: 5.72
# Peak Heights: 0.06727480045610035
# Peak Angle: 5.78
# Peak Heights: 0.06727480045610035
# Peak Angle: 5.82
# Peak Heights: 0.07753705815279362
# Peak Angle: 5.86
# Peak Heights: 0.07183580387685291
# Peak Angle: 5.98
# Peak Heights: 0.06955530216647662
# Peak Angle: 6.06
# Peak Heights: 0.07297605473204105
# Peak Angle: 6.1
# Peak Heights: 0.06385404789053592
# Peak Angle: 6.22
# Peak Heights: 0.06385404789053592
# Peak Angle: 6.32
# Peak Heights: 0.06841505131128849
# Peak Angle: 6.38
# Peak Heights: 0.07183580387685291
# ...

# %%
XCBs.intensities = XCBs.intensities / 0.7468643101482326

# %%
for i in range(0, len(XR5s.peakAngles)):
    print("Peak Angle:", XR5s.peakAngles[i])
    print("Peak Heights:", XR5s.peakHeights[i])
# Out:
# Peak Angle: 6.2
# Peak Heights: 0.023191943851083308
# Peak Angle: 13.94
# Peak Heights: 0.38388770216661583
# Peak Angle: 16.94
# Peak Heights: 0.021361000915471468
# Peak Angle: 18.88
# Peak Heights: 0.022276472383277388
# Peak Angle: 19.78
# Peak Heights: 0.10131217577052182
# Peak Angle: 20.58
# Peak Heights: 0.026853829722306988
# Peak Angle: 21.26
# Peak Heights: 0.03753433018004272
# Peak Angle: 21.38
# Peak Heights: 0.03692401586817211
# Peak Angle: 21.94
# Peak Heights: 0.03478791577662496
# Peak Angle: 22.4
# Peak Heights: 0.03417760146475435
# Peak Angle: 23.2
# Peak Heights: 0.03936527311565456
# Peak Angle: 24.28
# Peak Heights: 1.0
# Peak Angle: 25.44
# Peak Heights: 0.037229173024107415
# Peak Angle: 25.74
# Peak Heights: 0.03967043027158987
# Peak Angle: 26.38
# Peak Heights: 0.03783948733597803
# Peak Angle: 26.94
# Peak Heights: 0.03844980164784864
# Peak Angle: 27.54
# Peak Heights: 0.03753433018004272
# Peak Angle: 28.08
# Peak Heights: 0.2096429661275557
# ...

# %%
XR5s.intensities = XR5s.intensities / 0.1913335367714373

# %%
print(X20s.angles)
# Out:
# [[ 5.    5.02  5.04 ... 39.96 39.98 40.  ]]

# %% [markdown]
# Do a fast plot:

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(4, 3), dpi = 300)
#plt.plot(10, 20)
plt.plot(X20s.angles[0], X20s.intensities[0]+3, color = "r")
plt.plot(X25s.angles[0], X25s.intensities[0]+2)
plt.plot(XCBs.angles[0], XCBs.intensities[0]+1)
plt.plot(XR5s.angles[0], XR5s.intensities[0])
plt.xlabel("Angle")
plt.ylabel("Intensity")
plt.grid()
plt.show()
