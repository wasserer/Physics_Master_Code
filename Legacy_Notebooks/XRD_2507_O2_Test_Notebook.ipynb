# %% [markdown]
# # Test on the influence of the O2 Plasma treatment
# - Use the 20s 5000 RPM sample, but the XRD looks weired

# %%
import numpy as np
import matplotlib.pyplot as plt
from plot_module.xrd_analyzer import XRDAnalyzer

# %%
N20 = XRDAnalyzer()
N20.import_xrd_data(pathName='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/XRD/24072025_PSC_in_Plasma_Oven/N.txt')
Before = XRDAnalyzer()
Before.import_xrd_data(pathName='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/XRD/24072025_PSC_in_Plasma_Oven/Before.txt')
After = XRDAnalyzer()
After.import_xrd_data(pathName='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/XRD/24072025_PSC_in_Plasma_Oven/After2.txt')

# %%
print(N20.angles)
print(N20.intensities)
# Out:
# [[ 5.    5.02  5.04 ... 39.96 39.98 40.  ]]
# [[0.08177905 0.08321377 0.09182209 ... 0.15208034 0.18651363 0.17216643]]

# %%
plt.figure(figsize = (9, 7))
#plt.plot(N20.angles[0], N20.intensities[0], color = 'r', label = "N20")
plt.plot(Before.angles[0], Before.intensities[0], color = 'b', label = "Before")
plt.plot(After.angles[0], After.intensities[0], color = 'g', label = "After")
#Plot the curve afterwards
plt.xlabel("Angle in 2$\theta$")
plt.ylabel("Intensity a. u.")
#plt.yscale('log')
plt.legend()
plt.grid()

# %%
plt.figure(figsize = (9, 7))
#plt.plot(N20.angles[0], N20.intensities[0], color = 'r', label = "N20")
plt.plot(Before.angles[0], Before.intensities[0], color = 'b', label = "Before")
plt.plot(After.angles[0], After.intensities[0], color = 'g', label = "After")
#Plot the curve afterwards
plt.xlabel("Angle in 2$\theta$")
plt.ylabel("Intensity a. u.")
plt.yscale('log')
plt.legend()
plt.grid()

# %%
BeforeA = XRDAnalyzer()
BeforeA.import_xrd_data(pathName='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/XRD/24072025_PSC_in_Plasma_Oven/Perovskite_layer.txt')
AfterA = XRDAnalyzer()
AfterA.import_xrd_data(pathName='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/XRD/24072025_PSC_in_Plasma_Oven/Perovskite_layer_after.txt')

# %%
plt.figure(figsize = (9, 7))
#plt.plot(N20.angles[0], N20.intensities[0], color = 'r', label = "N20")
plt.plot(BeforeA.angles[0], BeforeA.intensities[0], color = 'b', label = "Before")
plt.plot(AfterA.angles[0], AfterA.intensities[0], color = 'g', label = "After")
#Plot the curve afterwards
plt.xlabel("Angle in 2$\theta$")
plt.ylabel("Intensity a. u.")
#plt.yscale('log')
plt.legend()
plt.grid()
