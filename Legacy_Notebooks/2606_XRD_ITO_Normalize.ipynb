# %% [markdown]
# # Short Code to plot the normalized ITO:
# - Import the data
# - Normalize the data with ITO peak

# %%
import numpy as np
from plot_module.xrd_analyzer import XRDAnalyzer
import matplotlib.pyplot as plt

# %%
N = XRDAnalyzer()
R = XRDAnalyzer()
S = XRDAnalyzer()
N.import_xrd_data(pathName='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/XRD/26062025/Data/N.txt')
R.import_xrd_data(pathName='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/XRD/26062025/Data/R.txt')
S.import_xrd_data(pathName='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/XRD/26062025/Data/S.txt')
N.find_peaks_and_FWHM()
R.find_peaks_and_FWHM()
S.find_peaks_and_FWHM()

# %%
for i in range (0, len(N.peakAngles)):
    print("peak Angles:", N.peakAngles[i], "Peak Height:", N.peakHeights[i])
# Out:
# peak Angles: 5.06 Peak Height: 0.10329985652797705
# peak Angles: 5.1 Peak Height: 0.12195121951219512
# peak Angles: 5.2 Peak Height: 0.10760401721664276
# peak Angles: 5.28 Peak Height: 0.11621233859397417
# peak Angles: 5.38 Peak Height: 0.09899569583931134
# peak Angles: 5.46 Peak Height: 0.10616929698708752
# peak Angles: 5.54 Peak Height: 0.08177905308464849
# peak Angles: 5.58 Peak Height: 0.09182209469153516
# peak Angles: 5.66 Peak Height: 0.07747489239598278
# peak Angles: 5.72 Peak Height: 0.08608321377331421
# peak Angles: 5.8 Peak Height: 0.12051649928263988
# peak Angles: 5.86 Peak Height: 0.08895265423242468
# peak Angles: 5.9 Peak Height: 0.08321377331420372
# peak Angles: 6.04 Peak Height: 0.08751793400286945
# peak Angles: 6.12 Peak Height: 0.08034433285509325
# peak Angles: 6.22 Peak Height: 0.08321377331420372
# peak Angles: 6.3 Peak Height: 0.08608321377331421
# peak Angles: 6.4 Peak Height: 0.09469153515064563
# peak Angles: 6.5 Peak Height: 0.08751793400286945
# ...

# %%
N.intensities = N.intensities / 0.9139167862266858

# %%
for i in range (0, len(R.peakAngles)):
    print("peak Angles:", R.peakAngles[i], "Peak Height:", R.peakHeights[i])
# Out:
# peak Angles: 5.1 Peak Height: 0.11428571428571428
# peak Angles: 5.16 Peak Height: 0.09924812030075188
# peak Angles: 5.3 Peak Height: 0.11879699248120301
# peak Angles: 5.42 Peak Height: 0.0887218045112782
# peak Angles: 5.54 Peak Height: 0.1037593984962406
# peak Angles: 5.74 Peak Height: 0.09172932330827067
# peak Angles: 5.8 Peak Height: 0.12330827067669173
# peak Angles: 5.96 Peak Height: 0.10225563909774436
# peak Angles: 6.02 Peak Height: 0.09323308270676692
# peak Angles: 6.1 Peak Height: 0.09172932330827067
# peak Angles: 6.14 Peak Height: 0.09022556390977443
# peak Angles: 6.24 Peak Height: 0.07218045112781955
# peak Angles: 6.3 Peak Height: 0.08571428571428572
# peak Angles: 6.36 Peak Height: 0.09022556390977443
# peak Angles: 6.48 Peak Height: 0.07969924812030076
# peak Angles: 6.62 Peak Height: 0.0887218045112782
# peak Angles: 6.66 Peak Height: 0.081203007518797
# peak Angles: 6.7 Peak Height: 0.07969924812030076
# peak Angles: 6.76 Peak Height: 0.07067669172932331
# ...

# %%
R.intensities = R.intensities /0.9278195488721804

# %%
for i in range (0, len(S.peakAngles)):
    print("peak Angles:", S.peakAngles[i], "Peak Height:", S.peakHeights[i])
# Out:
# peak Angles: 5.02 Peak Height: 0.10090361445783133
# peak Angles: 5.24 Peak Height: 0.10843373493975904
# peak Angles: 5.32 Peak Height: 0.09939759036144578
# peak Angles: 5.4 Peak Height: 0.0963855421686747
# peak Angles: 5.46 Peak Height: 0.10391566265060241
# peak Angles: 5.5 Peak Height: 0.09036144578313253
# peak Angles: 5.54 Peak Height: 0.09036144578313253
# peak Angles: 5.6 Peak Height: 0.08734939759036145
# peak Angles: 5.64 Peak Height: 0.08433734939759036
# peak Angles: 5.7 Peak Height: 0.09939759036144578
# peak Angles: 5.74 Peak Height: 0.09789156626506024
# peak Angles: 5.8 Peak Height: 0.09789156626506024
# peak Angles: 5.84 Peak Height: 0.09337349397590361
# peak Angles: 5.94 Peak Height: 0.09789156626506024
# peak Angles: 5.98 Peak Height: 0.0858433734939759
# peak Angles: 6.06 Peak Height: 0.07981927710843373
# peak Angles: 6.1 Peak Height: 0.08885542168674698
# peak Angles: 6.16 Peak Height: 0.09186746987951808
# peak Angles: 6.24 Peak Height: 0.0858433734939759
# ...

# %%
S.intensities = S.intensities / 0.9503012048192772

# %% [markdown]
# Plot the figures:

# %%
plt.figure(figsize=(7, 5), dpi = 300)
plt.plot(N.angles[0], N.intensities[0], label = "Anti-Solvent at 20s")
#plt.plot(R.angles[0], R.intensities[0], label = "RPM at 3000s")
plt.plot(S.angles[0], S.intensities[0], label = "Anti solvent at 15s")
plt.legend()
plt.grid()
