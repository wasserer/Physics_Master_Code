# %% [markdown]
# # A short analyzer for solsim

# %%
import numpy as np
import scipy as sp
from plot_module.solsim_analyzer import solarSimulator
from plot_module.colors import color

# %% [markdown]
# ## Import the data
# - The data are hand selected, which only contain "Good Cells" and "Forward scanning"

# %%
analyzer = solarSimulator(folderPath='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/SolSim/09_01_2025/GoodCells')
analyzer.CDC = 1000/0.145
analyzer.loadFolderData()
analyzer.logData()
# Out:
# [-0.34359346 -0.71507833 -1.05925664 -1.38920762 -1.70263659 -1.99727192
#  -2.27896546 -2.54731224 -2.80712222 -3.05262368 -3.28876214 -3.5120531
#  -3.72123435 -3.91827043 -4.10458038 -4.27626443 -4.42405754 -4.55846315
#  -4.67015    -4.75971601 -4.81745985 -4.85012102 -4.86116741 -4.84673744
#  -4.81825016 -4.77347551 -4.71342441 -4.65134188 -4.57543092 -4.49639004
#  -4.41824138 -4.3315884  -0.02865965  0.07158791  0.1715783   0.2713791
#   0.37107712  0.47063721  0.57007761  0.66992034  0.76949722  0.86874452
#   0.96702589  1.06669582  1.16551222  1.26418269  1.36188909  1.46013642
#   1.56022269  1.65821429  1.75503448]
# PIN_1_px4_Light_forward_0
# [-0.20817774 -0.52697311 -0.82784884 -1.09506566 -1.34245189 -1.55657356
#  -1.7771442  -1.98951365 -2.19507073 -2.38761817 -2.57336069 -2.75962054
#  -2.93278109 -3.09756815 -3.26458628 -3.42144857 -3.57525744 -3.72025219
#  -3.87007418 -3.99228343 -4.10845781 -4.20266495 -4.27906811 -4.3377827
# ...

# %% [markdown]
# ### Log the data

# %%
analyzer.logData()

# %% [markdown]
# ### Now do some basic multiplots:

# %%
graphColor = color.matlab()
analyzer.IVMultiPlot(labelMode=False)

# %% [markdown]
# ## Compare two different Groups:
# - Here I mean compare 15s(S) and 20s(N)

# %%
groupN = solarSimulator(folderPath='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/SolSim/26_06_2025_R5/Good_Cells/N')
groupS = solarSimulator(folderPath='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/SolSim/26_06_2025_R5/Good_Cells/S')

groupS.loadFolderData()
groupN.loadFolderData()

groupN.boxPlot(data1=groupN.PCE, data2=groupS.PCE, names=["5000RPM, 20s", "5000 RPM, 15S"])
# Out:
# [-0.49849691 -0.97912827 -1.38110248 -1.70350957 -1.94605325 -2.17275664
#  -2.34382909 -2.49664705 -2.59372429 -2.69467783 -2.79483641 -2.8672264
#  -2.93621748 -3.00426037 -3.04910529 -3.09548096 -3.12298684 -3.14282091
#  -3.14283532 -3.15724697 -3.17024659 -3.16631979 -3.16045857 -3.1406139
#  -3.13484759 -3.11401171 -3.08635275 -3.06055879 -3.03417439 -2.9960121
#  -2.95556919 -2.91214996 -2.86226644 -2.80760981 -2.75621546 -2.70240377
#  -2.63799924 -2.57170697 -2.4955591  -2.42655213 -2.35207305 -2.27477617
#  -2.1947785  -2.11114481 -2.021573   -1.93098812 -1.83675493 -1.74004527
#  -1.6386646  -1.53298961 -1.42569462 -1.31617675 -1.20365157 -1.08784394
#  -0.96853378 -0.84582332 -0.71998992 -0.59098882 -0.45850646 -0.32282435
#  -0.18376241 -0.04133879]
# S5_px2_Light_forward_0
# [-0.67636001 -2.70322331 -4.31425737 -5.55465159 -6.48276245 -7.15556708
#  -7.61566095 -7.91377377 -8.1079898  -8.21061608 -8.24720302 -8.23759755
# ...
