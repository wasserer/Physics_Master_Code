# %%
import numpy as np
import scipy as super
import matplotlib.pyplot as plt
from plot_module.solsim_analyzer import solarSimulator

# %% [markdown]
# Only good cells are imported

# %%
folderPath_goodCells = '/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/SolSim/04_06_2025_Cs_Test/GoodCells'

analyzer = solarSimulator(folderPath=folderPath_goodCells)
analyzer.loadFolderData()
analyzer.IVMultiPlot(saveName="NewResult.png")
# Out:
# [ -1.04379431  -4.14185468  -6.43920102  -8.0820453   -9.21735592
#   -9.96549333 -10.44036602 -10.71860703 -10.86341023 -10.91143666
#  -10.89799701 -10.83876003 -10.74767746 -10.63357037 -10.50582327
#  -10.36152497 -10.21338016 -10.05472438  -9.89655636  -9.73693394
#   -9.56739823  -9.39667184  -9.22669168  -9.05462251  -8.88196004
#   -8.70884346  -8.53571877  -8.35898077  -8.18303465  -8.0071519
#   -7.83253661  -7.65369133  -7.47700418  -7.29872659  -7.12635658
#   -6.95032563  -6.76650109  -6.58708758  -6.4089374   -6.22946872
#   -6.05366382  -5.87138379  -5.69127568  -5.51116982  -5.33116931
#   -5.15067063  -4.9713112   -4.79053342  -4.61038591  -4.42930905
#   -4.2495774   -4.06705342  -3.88611417  -3.70518692  -3.52350656
#   -3.34439173  -3.16195405  -2.97780248  -2.79613989  -2.61406174
#   -2.43170886  -2.2494548   -2.0669136   -1.88531757  -1.70205453
#   -1.5191076   -1.33596526  -1.15304546  -0.96989372  -0.78669462
# ...

# %%
analyzer.logData()

# %%
plt.hist(analyzer.PCE)
# Out:
# (array([4., 3., 1., 1., 2., 0., 2., 2., 2., 7.]),
#  array([ 0.09943092,  1.59549742,  3.09156393,  4.58763043,  6.08369694,
#          7.57976345,  9.07582995, 10.57189646, 12.06796297, 13.56402947,
#         15.06009598]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(analyzer.Isc)
# Out:
# (array([ 2.,  1.,  0.,  0.,  0.,  0.,  3.,  4.,  1., 13.]),
#  array([1.28689000e-03, 1.74406959e+00, 3.48685230e+00, 5.22963500e+00,
#         6.97241770e+00, 8.71520041e+00, 1.04579831e+01, 1.22007658e+01,
#         1.39435485e+01, 1.56863312e+01, 1.74291139e+01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(analyzer.Voc)
# Out:
# (array([11.,  7.,  1.,  0.,  0.,  2.,  1.,  0.,  0.,  2.]),
#  array([-0.872581  , -0.78790355, -0.7032261 , -0.61854865, -0.5338712 ,
#         -0.44919375, -0.3645163 , -0.27983885, -0.1951614 , -0.11048395,
#         -0.0258065 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(analyzer.FF)
# Out:
# (array([ 5.,  1.,  2.,  3.,  0.,  0.,  0.,  1.,  0., 12.]),
#  array([0.24123665, 0.29875864, 0.35628063, 0.41380263, 0.47132462,
#         0.52884661, 0.5863686 , 0.64389059, 0.70141258, 0.75893458,
#         0.81645657]),
#  <BarContainer object of 10 artists>)
