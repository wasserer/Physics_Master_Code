# %% [markdown]
# # XRD on 18.8.2025

# %%
import numpy as np
from plot_module.xrd_analyzer import XRDAnalyzer
import matplotlib.pyplot as plt

# %%
folder = ""  # Enter your file path/folder path in this place
color = ["#0072BD", "#D95319", "#EDB120", "#7E2F8E", "#77AC30", "#4DBEEE", "#A2142F"]

# %%
analyzer = XRDAnalyzer()
analyzer.import_xrd_folder(folderPath=folder)

# %%
analyzer.multiXRD(graphColor=color)

# %%
analyzer.find_peaks_and_FWHM(log=True)

# %%
xrd3 = XRDAnalyzer()
xrd3.import_xrd_data(pathName="")  # Enter your file path/folder path in this place
xrd3.find_peaks_and_FWHM(log=True)
