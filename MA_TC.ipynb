# %% [markdown]
# # Plot the temperature Profile:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
temperature_log = '/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/TC_1709_50Cycle/TC_1909_IV/TC_log/temperature_log.csv'

# %%
df = pd.read_csv(temperature_log)

# %%
df
# Out:
#                          Timestamp   Elapsed_s  Temp_A_C  Setpoint_C   Phase  \
# 0       2025-09-15T15:50:47.064804       0.043    20.052       19.98  sunlit
# 1       2025-09-15T15:50:47.093076       0.072    20.052       20.28  sunlit
# 2       2025-09-15T15:50:48.071960       1.050    20.056       20.57  sunlit
# 3       2025-09-15T15:50:49.070598       2.049    20.064       20.86  sunlit
# 4       2025-09-15T15:50:50.062904       3.041    20.077       21.15  sunlit
# ...                            ...         ...       ...         ...     ...
# 275995  2025-09-18T20:30:41.048687  275994.027    17.285       18.49  sunlit
# 275996  2025-09-18T20:30:42.053961  275995.032    17.608       18.79  sunlit
# 275997  2025-09-18T20:30:43.073417  275996.052    17.927       19.09  sunlit
# 275998  2025-09-18T20:30:44.079215  275997.058    18.277       19.39  sunlit
# 275999  2025-09-18T20:30:45.053705  275998.032    18.562       19.69  sunlit
#
#         Orbit
# 0           1
# ...

# %%
time_s = df["Elapsed_s"]
temperature = df["Temp_A_C"]
set_temp = df["Setpoint_C"]

# %%
temperature_difference = df["Setpoint_C"] - df["Temp_A_C"]

# %%
time_h = np.array(time_s / 3600)
temperature = np.array(temperature)

# %%
print(time_h)
print(temperature)
# Out:
# [1.19444444e-05 2.00000000e-05 2.91666667e-04 ... 7.66655700e+01
#  7.66658494e+01 7.66661200e+01]
# [20.052 20.052 20.056 ... 17.927 18.277 18.562]

# %%
plt.figure(figsize = (10, 4), dpi = 300)

plt.plot(time_h, set_temp, alpha = 1, color = "#ED7D31", label = "Set Temperature")
plt.plot(time_h, temperature, alpha = 0.8, color = "#5B8CBE", label = "Operation Temperature")
#plt.xlim(0, 3.2)
plt.ylim(-115, 80)
plt.xlabel("Time [h]")
plt.ylabel("Temperature [$^{\circ}$C]")
plt.legend()
plt.grid()

# %%
plt.figure(figsize = (10, 4), dpi = 300)
plt.plot(time_h, temperature_difference, alpha = 0.8, label = "Operation Temperature")
plt.xlim(40, 57)
plt.ylim(-10, 10)
plt.xlabel("Time [h]")
plt.ylabel("Temperature [$^{\circ}$C]")
plt.legend()
plt.grid()

# %%
plt.figure(figsize = (10, 4), dpi = 300)
plt.plot(time_h, temperature_difference, alpha = 0.8, label = "Operation Temperature")
plt.xlim(9, 11)
plt.ylim(-10, 10)
plt.xlabel("Time [hour]")
plt.ylabel("Temperature [$^{\circ}$C]")
plt.legend()
plt.grid()

# %%
fig, ax1 = plt.subplots(figsize=(8, 4), dpi = 300)

# Plot the first y-axis data
color1 = 'tab:blue'
ax1.set_xlabel('Time [h]')
ax1.set_ylim(-120, 80)
ax1.set_ylabel("Temperature [$^{\circ}$C]", color=color1)
ax1.plot(time_h, set_temp, color=color1, label='Set Temperature')
ax1.tick_params(axis='y', labelcolor=color1)

# Create the second y-axis sharing the same x-axis
ax2 = ax1.twinx()
color2 = 'tab:red'
ax2.set_ylabel('Temperature Difference [$^{\circ}$C]', color=color2)
ax2.plot(time_h, temperature_difference, color=color2, label='Temperature Difference')
ax2.tick_params(axis='y', labelcolor=color2)

#ax2.set_xlim(55.5, 70)
ax2.set_xlim(0, 12.25)
ax2.set_ylim(-15, 15)
# Optional: combine legends
lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='lower right')

plt.tight_layout()

# %%
fig, ax1 = plt.subplots(figsize=(8, 4), dpi = 300)

# Plot the first y-axis data
color1 = 'tab:blue'
ax1.set_xlabel('Time [h]')
ax1.set_ylim(-120, 80)
ax1.set_ylabel("Temperature [$^{\circ}$C]", color=color1)
ax1.plot(time_h, set_temp, color=color1, label='Set Temperature')
ax1.tick_params(axis='y', labelcolor=color1)

# Create the second y-axis sharing the same x-axis
ax2 = ax1.twinx()
color2 = 'tab:red'
ax2.set_ylabel('Temperature Difference [$^{\circ}$C]', color=color2)
ax2.plot(time_h, temperature_difference, color=color2, label='Temperature Difference')
ax2.tick_params(axis='y', labelcolor=color2)

ax2.set_xlim(55.5, 70)
#ax2.set_xlim(0, 12.25)
ax2.set_ylim(-140, 15)
# Optional: combine legends
lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
ax1.legend(lines_1 + lines_2, labels_1 + labels_2, loc='lower right')

plt.tight_layout()
