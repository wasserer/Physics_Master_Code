# %%
import numpy as np
from plot_module.solsim_analyzer import solarSimulator
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import the data:

# %%
analyzer = solarSimulator(folderPath='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/SolSim/13_08_AntiSolventTest')
analyzer.loadFolderData()
analyzer.logData()
# Out:
# [-0.57564475 -1.92825799 -2.96669511 -3.74899703 -4.33158237 -4.76164962
#  -5.07423039 -5.28578589 -5.4432588  -5.5448656  -5.61370276 -5.66440133
#  -5.6886327  -5.69679822 -5.68625176 -5.67029841 -5.64673809 -5.60909616
#  -5.57033698 -5.51836609 -5.46383872 -5.40588204 -5.34415874 -5.27771927
#  -5.20892789 -5.13623252 -5.05845156 -4.98089453 -4.90175348 -4.82033345
#  -4.73562623 -4.65112658 -4.56490401 -4.47644371 -4.38711174 -4.29574709
#  -4.20457116 -4.11092131 -4.01714309 -3.92002808 -3.82414203 -3.72511283
#  -3.62723194 -3.52767049 -3.42667225 -3.32585458 -3.22267962 -3.11938688
#  -3.01477868 -2.91037246 -2.80486946 -2.69853752 -2.59205719 -2.48507331
#  -2.37820903 -2.26961725 -2.16043337 -2.0513724  -1.94250907 -1.83274467
#  -1.7222426  -1.61121973 -1.50086013 -1.38967404 -1.27845773 -1.16628355
#  -1.05384826 -0.94121532 -0.8286379  -0.715685   -0.6023663  -0.48885058
#  -0.37516651 -0.26123495 -0.14704038 -0.03270641]
# 35_3_px4_Light_reverse_0
# []
# ...

# %% [markdown]
# Setup a filter:

# %%
print(analyzer.Voc)
# Out:
# [-0.85, 0.154839, 0.132258, -0.804839, -0.906452, 0.154839, -0.906452, -0.895161, -0.00322581, 0.0870968, -0.0145161, -0.929032, -0.883871, -0.940323, -0.906452, -0.872581, -0.454839, -0.00322581, -0.00322581, -0.906452, -0.872581, -0.0145161, -0.929032, -0.883871, 0.166129, -0.0145161, -0.00322581, 0.0306452, -0.375806, -0.906452, -0.883871, 0.143548, -0.804839, -0.906452, -0.85, -0.816129, 0.166129, -0.83871, 0.00806452, 0.177419, 0.166129, -0.330645, 0.143548, 0.0645161, 0.132258, 0.00806452, 0.0193548, -0.872581, -0.251613, 0.00806452, -0.872581, 0.18871, -0.85, 0.166129, 0.00806452, 0.0645161, -0.00322581, 0.0419355, 0.109677, -0.85, -0.85, 0.0532258, -0.00322581, 0.2, 0.177419, 0.154839, -0.85, 0.0983871, 0.0306452, -0.872581, -0.996774, -0.872581, 0.154839, 0.0532258, 0.00806452, 0.00806452, 0.109677, 0.166129, 0.154839, -0.195161, 0.0645161, -0.83871, 0.0532258, -0.737097, -0.624194, -0.85, -0.86129, -0.872581, -0.872581, -0.83871, -0.940323, -0.85, -0.83871, -0.691935, -0.90
# ...

# %%
for i in range(len(analyzer.PCE)):
    plt.figure()
    plt.plot(analyzer.voltages[i], analyzer.currents[i], label = f"The PCE is: {analyzer.PCE[i]}, and the Voc is: {analyzer.Voc[i]}")
    plt.legend()
    plt.title(f"The IV curve of {analyzer.labels[i]}")
    plt.grid()

    plt.xlim(-1, 0.2)
    plt.ylim(-1, 25)
# Out:
# /var/folders/gk/j7sbhfc93v5gxyqp6ltt1dqc0000gn/T/ipykernel_38671/2033579450.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()
