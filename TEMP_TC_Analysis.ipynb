# %% [markdown]
# # Temporary analysis for TC on Sept. 15

# %%
#Import relevant libs:
import numpy as np
from plot_module.tc_analyzer import ThermalCycling
from plot_module.solsim_analyzer import solarSimulator
from plot_module.Spectra import Spectroscopy
import matplotlib.pyplot as plt

# %% [markdown]
# ### Sort TC Data into folders:

# %%
TC_folderPath = '/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/TC_1709_50Cycle/TC_1909_IV'

# %%
TC = ThermalCycling(folderPath=TC_folderPath)
TC.sortData()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 TC = ThermalCycling(folderPath=TC_folderPath)
# ----> 2 TC.sortData()
#
# File ~/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/Script/Physics_Master/plot_module/tc_analyzer.py:15, in ThermalCycling.sortData(self)
#      13 identifiers = [f"px{i}" for i in range(1, 7)]
#      14 #identifiersSpectra = "Spectrum"
# ---> 15 for filename in os.listdir(self.folderPath):
#      16     file_path = os.path.join(self.folderPath, filename)
#      17     if not os.path.isfile(file_path):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/TEMP_TC16092025'

# %% [markdown]
# ### Spectra Analysis:

# %%
Spectra_FolderPath = '/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/TEMP_TC16092025/Spectra'
Spectra = Spectroscopy(folderPath=Spectra_FolderPath)

#Spectra.importDark(darkFilePath='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/TEMP_TC16092025/Spectra/Dark/20250915_155012_Thermal_Cycling_Spectrum_dark_Dark.dat')
#spectra.importDark(darkFilePath='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/06082025/Thermal_Cycling_2025-08-05_14-59-47/Spectra/Dark/20250805_150250_Thermal_Cycling_Spectrum_dark_Dark.dat')
Spectra.Pipeline(darkFolder='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/TEMP_TC16092025/Spectra/Dark/20250915_155012_Thermal_Cycling_Spectrum_dark_Dark.dat')
# Out:
# Debug: 20250916_085854_Thermal_Cycling_Spectrum_Light_c0514-2.dat
# Debug: 20250915_210047_Thermal_Cycling_Spectrum_Light_c0155-1.dat
# Debug: 20250916_043659_Thermal_Cycling_Spectrum_Light_c0383-3.dat
# Debug: 20250916_000253_Thermal_Cycling_Spectrum_Light_c0246-2.dat
# Debug: 20250915_210647_Thermal_Cycling_Spectrum_Light_c0158-1.dat
# Debug: 20250916_041059_Thermal_Cycling_Spectrum_Light_c0370-3.dat
# Debug: 20250915_162500_Thermal_Cycling_Spectrum_Light_c0017-3.dat
# Debug: 20250915_160700_Thermal_Cycling_Spectrum_Light_c0008-3.dat
# Debug: 20250916_071854_Thermal_Cycling_Spectrum_Light_c0464-2.dat
# Debug: 20250915_205654_Thermal_Cycling_Spectrum_Light_c0153-2.dat
# Debug: 20250915_160100_Thermal_Cycling_Spectrum_Light_c0005-3.dat
# Debug: 20250915_163854_Thermal_Cycling_Spectrum_Light_c0024-2.dat
# Debug: 20250916_030247_Thermal_Cycling_Spectrum_Light_c0336-1.dat
# Debug: 20250916_090100_Thermal_Cycling_Spectrum_Light_c0515-3.dat
# ...

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.scatter(Spectra.timestampAbsHN, Spectra.bandGap)
#plt.ylim(1.45,)
plt.xlim(0, 8)
# Out:
# (0.0, 18.0)

# %%
number = 100
import matplotlib.pyplot as plt

for num in range (0, number):
    plt.figure()
    plt.plot(Spectra.eV, Spectra.valueTaucs[num], label='Tauc Plot at temperature {:.1f} Degree'.format(Spectra.temperatures[num]))
    plt.plot(Spectra.eV, Spectra.tauc_slope_b[num] + Spectra.tauc_slope[num] * Spectra.eV, label=r'Fit Line, band gap = {:.3f} eV'.format(Spectra.bandGap[num]))
    plt.xlim(1.45, 2)
    plt.ylim(0,2)
    plt.xlabel('Energy (eV)')
    plt.ylabel('Tauc Plot (Absorbance * photon energy)^0.5')
    plt.title('Tauc Plot for Band Gap Calculation')
    plt.legend()
    plt.grid()
# Out:
# /var/folders/gk/j7sbhfc93v5gxyqp6ltt1dqc0000gn/T/ipykernel_4462/2891169374.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 6
#       4 for num in range (0, number):
#       5     plt.figure()
# ----> 6     plt.plot(Spectra.eV, Spectra.valueTaucs[num], label='Tauc Plot at temperature {:.1f} Degree'.format(Spectra.temperatures[num]))
#       7     plt.plot(Spectra.eV, Spectra.tauc_slope_b[num] + Spectra.tauc_slope[num] * Spectra.eV, label=r'Fit Line, band gap = {:.3f} eV'.format(Spectra.bandGap[num]))
# ...

# %% [markdown]
# ### Solar Simulator:

# %%
px1 = solarSimulator(folderPath='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/TEMP_TC16092025/px1')
px2 = solarSimulator(folderPath='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/TEMP_TC16092025/px2')
px3 = solarSimulator(folderPath='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/TEMP_TC16092025/px3')
px4 = solarSimulator(folderPath='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/TEMP_TC16092025/px4')
px5 = solarSimulator(folderPath='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/TEMP_TC16092025/px5')
px6 = solarSimulator(folderPath='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/TEMP_TC16092025/px6')

# %%
px1.loadFolderData_Cycling()
px2.loadFolderData_Cycling()
px3.loadFolderData_Cycling()
px4.loadFolderData_Cycling()
px5.loadFolderData_Cycling()
px6.loadFolderData_Cycling()
# Out:
# Line 6: # Measured Temperature: 69.79 C
# [-0.85439812 -1.52442985 -2.06013562 -2.56555411 -2.9381995  -3.14470477
#  -3.36397116 -3.55371353 -3.68519969 -3.69684707 -3.75442886 -3.79938107
#  -3.82207153 -3.80273952 -3.81571372 -3.8356025  -3.81124725 -3.71200453
#  -3.71446701 -3.73994829 -3.65826994 -3.56525175 -3.55501896 -3.49643688
#  -3.41585577 -3.37899064 -3.39020249 -3.30530816 -3.214019   -3.16045718
#  -3.13021354 -3.0286378  -2.94541599 -2.91187932 -2.89875759 -2.80906915
#  -2.72225149 -2.69615376 -2.6374274  -2.53661207 -2.47959148 -2.41857532
#  -2.35892744 -2.27951788 -2.24367757 -2.17900993 -2.07465693 -1.99762189
#  -1.96225221 -1.92016148 -1.83874294 -1.77417851 -1.72545332 -1.66575821
#  -1.59355748 -1.53382038 -1.4781556  -1.39376446 -1.30180545 -1.23519107
#  -1.17671692 -1.10345303 -1.02889569 -0.97034538 -0.90606897 -0.82976899
#  -0.76084865 -0.69869603 -0.62272446 -0.54532791 -0.47620407 -0.41498112
# ...

# %%
fig, ax1 = plt.subplots(figsize=(7, 5), dpi = 300)
ax1.scatter(px1.timestampAbsH, px1.PCE, color = 'red', label='PCE')
ax1.set_ylabel('PCE', color='r')
ax1.tick_params(axis='y', labelcolor='r')

# 创建第二个 y 轴（右边）
ax2 = ax1.twinx()
ax2.plot(px1.timestampAbsH, px1.temperature, 'b--', label='Temperature')
ax2.set_ylabel('Temperature', color='b')
ax2.tick_params(axis='y', labelcolor='b')
#plt.xlim(0, 4)
# 添加标题
plt.title("The temperature and the PCE of the pixel 1 during the thermal cycling")
# Out:
# Text(0.5, 1.0, 'The temperature and the PCE of the pixel 1 during the thermal cycling')

# %%
fig, ax1 = plt.subplots(figsize=(7, 5), dpi = 300)
ax1.scatter(px2.timestampAbsH, px2.PCE, color = 'red', label='PCE')
ax1.set_ylabel('PCE', color='r')
ax1.tick_params(axis='y', labelcolor='r')

# 创建第二个 y 轴（右边）
ax2 = ax1.twinx()
ax2.plot(px2.timestampAbsH, px2.temperature, 'b--', label='Temperature')
ax2.set_ylabel('Temperature', color='b')
ax2.tick_params(axis='y', labelcolor='b')
#plt.xlim(0, 4)
# 添加标题
plt.title("The temperature and the PCE of the pixel 2 during the thermal cycling")
# Out:
# Text(0.5, 1.0, 'The temperature and the PCE of the pixel 2 during the thermal cycling')

# %%
fig, ax1 = plt.subplots(figsize=(7, 5), dpi = 300)
ax1.scatter(px3.timestampAbsH, px3.PCE, color = 'red', label='PCE')
ax1.set_ylabel('PCE', color='r')
ax1.tick_params(axis='y', labelcolor='r')

# 创建第二个 y 轴（右边）
ax2 = ax1.twinx()
ax2.plot(px3.timestampAbsH, px3.temperature, 'b--', label='Temperature')
ax2.set_ylabel('Temperature', color='b')
ax2.tick_params(axis='y', labelcolor='b')
#plt.xlim(0, 4)
# 添加标题
plt.title("The temperature and the PCE of the pixel 3 during the thermal cycling")
# Out:
# Text(0.5, 1.0, 'The temperature and the PCE of the pixel 3 during the thermal cycling')

# %%
fig, ax1 = plt.subplots(figsize=(7, 5), dpi = 300)
ax1.scatter(px4.timestampAbsH, px4.PCE, color = 'red', label='PCE')
ax1.set_ylabel('PCE', color='r')
ax1.tick_params(axis='y', labelcolor='r')

# 创建第二个 y 轴（右边）
ax2 = ax1.twinx()
ax2.plot(px4.timestampAbsH, px4.temperature, 'b--', label='Temperature')
ax2.set_ylabel('Temperature', color='b')
ax2.tick_params(axis='y', labelcolor='b')
#plt.xlim(0, 4)
# 添加标题
plt.title("The temperature and the PCE of the pixel 4 during the thermal cycling")
# Out:
# Text(0.5, 1.0, 'The temperature and the PCE of the pixel 4 during the thermal cycling')

# %%
fig, ax1 = plt.subplots(figsize=(7, 5), dpi = 300)
ax1.scatter(px5.timestampAbsH, px5.PCE, color = 'red', label='PCE')
ax1.set_ylabel('PCE', color='r')
ax1.tick_params(axis='y', labelcolor='r')

# 创建第二个 y 轴（右边）
ax2 = ax1.twinx()
ax2.plot(px5.timestampAbsH, px5.temperature, 'b--', label='Temperature')
ax2.set_ylabel('Temperature', color='b')
ax2.tick_params(axis='y', labelcolor='b')
#plt.xlim(0, 4)
# 添加标题
plt.title("The temperature and the PCE of the pixel 5 during the thermal cycling")
# Out:
# Text(0.5, 1.0, 'The temperature and the PCE of the pixel 5 during the thermal cycling')

# %%
fig, ax1 = plt.subplots(figsize=(7, 5), dpi = 300)
ax1.scatter(px6.timestampAbsH, px6.PCE, color = 'red', label='PCE')
ax1.set_ylabel('PCE', color='r')
ax1.tick_params(axis='y', labelcolor='r')

# 创建第二个 y 轴（右边）
ax2 = ax1.twinx()
ax2.plot(px6.timestampAbsH, px6.temperature, 'b--', label='Temperature')
ax2.set_ylabel('Temperature', color='b')
ax2.tick_params(axis='y', labelcolor='b')
#plt.xlim(0, 4)
# 添加标题
plt.title("The temperature and the PCE of the pixel 6 during the thermal cycling")
# Out:
# Text(0.5, 1.0, 'The temperature and the PCE of the pixel 6 during the thermal cycling')
