# %% [markdown]
# # This is the formal notebook for Thermal Cycling Analysis on August the 6th.
# - This part is to analyze and plot the IV curve

# %%
import numpy as np
from plot_module.solsim_analyzer import solarSimulator
import matplotlib.pyplot as plt
from plot_module.tc_analyzer import ThermalCycling

# %% [markdown]
# #### Toolbox: Sort the files(Don't exicute it later)

# %%
rawFolder = '/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/06082025_Temp/Test1_8_Orbit_2025-07-28_18-26-05'

# %%
sort = ThermalCycling(folderPath=rawFolder)
sort.sortData()

# %% [markdown]
# ## Import different pixel, and analyze them:

# %%
px1 = solarSimulator(folderPath='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/06082025_Temp/Test1_8_Orbit_2025-07-28_18-26-05/px1')
px2 = solarSimulator(folderPath='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/06082025_Temp/Test1_8_Orbit_2025-07-28_18-26-05/px2')
px3 = solarSimulator(folderPath='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/06082025_Temp/Test1_8_Orbit_2025-07-28_18-26-05/px3')
px4 = solarSimulator(folderPath='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/06082025_Temp/Test1_8_Orbit_2025-07-28_18-26-05/px4')
px5 = solarSimulator(folderPath='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/06082025_Temp/Test1_8_Orbit_2025-07-28_18-26-05/px5')
px6 = solarSimulator(folderPath='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/06082025_Temp/Test1_8_Orbit_2025-07-28_18-26-05/px6')

# %%
px1.loadFolderData_Cycling()
px2.loadFolderData_Cycling()
px3.loadFolderData_Cycling()
px4.loadFolderData_Cycling()
px5.loadFolderData_Cycling()
px6.loadFolderData_Cycling()
# Out:
# Line 6: # Measured Temperature: 68.69 C
# [-0.21210853 -0.46842784 -0.64788422 -0.79756243 -0.91746202 -0.99031263
#  -1.03226403 -1.08009291 -1.10469818 -1.10727858 -1.12339908 -1.14534503
#  -1.14267632 -1.11953636 -1.1168208  -1.11740968 -1.09359019 -1.07633413
#  -1.07193187 -1.0690552  -1.03461797 -1.00935443 -0.99954186 -0.97954897
#  -0.94519751 -0.92251137 -0.91326533 -0.89262918 -0.85839105 -0.84470212
#  -0.83819616 -0.80795474 -0.77798026 -0.77144044 -0.75650278 -0.72643874
#  -0.70015544 -0.68482648 -0.66126737 -0.62905945 -0.60655232 -0.59344606
#  -0.56607342 -0.54111764 -0.52293068 -0.50129886 -0.47326913 -0.44838761
#  -0.42731119 -0.40325703 -0.37451169 -0.34869469 -0.32793038 -0.30534285
#  -0.2785831  -0.25498547 -0.23269613 -0.2082565  -0.18250157 -0.15754919
#  -0.13321355 -0.10799633 -0.08260143 -0.05811624 -0.00728008  0.01814425]
# Line 6: # Measured Temperature: 64.73 C
# 20250729_074030_Test1_8_Orbit_px1_Light_forward_c397
# ...

# %%
fig, ax1 = plt.subplots(figsize=(9, 7), dpi = 300)
ax1.plot(px1.timestampAbsH, px1.PCE, 'r-', label='PCE')
ax1.set_ylabel('PCE', color='r')
ax1.tick_params(axis='y', labelcolor='r')

# 创建第二个 y 轴（右边）
ax2 = ax1.twinx()
ax2.plot(px1.timestampAbsH, px1.temperature, 'b--', label='Temperature')
ax2.set_ylabel('Temperature', color='b')
ax2.tick_params(axis='y', labelcolor='b')

# 添加标题
plt.title("The temperature and the PCE of the pixel 1 during the thermal cycling")
# Out:
# Text(0.5, 1.0, 'The temperature and the PCE of the pixel 1 during the thermal cycling')

# %%
fig, ax1 = plt.subplots(figsize=(9, 7), dpi = 300)
ax1.plot(px2.timestampAbsH, px2.PCE, 'r-', label='PCE')
ax1.set_ylabel('PCE', color='r')
ax1.tick_params(axis='y', labelcolor='r')

# 创建第二个 y 轴（右边）
ax2 = ax1.twinx()
ax2.plot(px2.timestampAbsH, px2.temperature, 'b--', label='Temperature')
ax2.set_ylabel('Temperature', color='b')
ax2.tick_params(axis='y', labelcolor='b')

# 添加标题
plt.title("The temperature and the PCE of the pixel 2 during the thermal cycling")
# Out:
# Text(0.5, 1.0, 'The temperature and the PCE of the pixel 2 during the thermal cycling')

# %%
fig, ax1 = plt.subplots(figsize=(9, 7), dpi = 300)
ax1.plot(px3.timestampAbsH, px3.PCE, 'r-', label='PCE')
ax1.set_ylabel('PCE', color='r')
ax1.tick_params(axis='y', labelcolor='r')

# 创建第二个 y 轴（右边）
ax2 = ax1.twinx()
ax2.plot(px3.timestampAbsH, px3.temperature, 'b--', label='Temperature')
ax2.set_ylabel('Temperature', color='b')
ax2.tick_params(axis='y', labelcolor='b')

# 添加标题
plt.title("The temperature and the PCE of the pixel 3 during the thermal cycling")
# Out:
# Text(0.5, 1.0, 'The temperature and the PCE of the pixel 3 during the thermal cycling')

# %%
fig, ax1 = plt.subplots(figsize=(9, 7), dpi = 300)
ax1.plot(px4.timestampAbsH, px4.PCE, 'r-', label='PCE')
ax1.set_ylabel('PCE', color='r')
ax1.tick_params(axis='y', labelcolor='r')

# 创建第二个 y 轴（右边）
ax2 = ax1.twinx()
ax2.plot(px4.timestampAbsH, px4.temperature, 'b--', label='Temperature')
ax2.set_ylabel('Temperature', color='b')
ax2.tick_params(axis='y', labelcolor='b')

# 添加标题
plt.title("The temperature and the PCE of the pixel 4 during the thermal cycling")
# Out:
# Text(0.5, 1.0, 'The temperature and the PCE of the pixel 4 during the thermal cycling')

# %%
fig, ax1 = plt.subplots(figsize=(9, 7), dpi = 300)
ax1.plot(px5.timestampAbsH, px5.PCE, 'r-', label='PCE')
ax1.set_ylabel('PCE', color='r')
ax1.tick_params(axis='y', labelcolor='r')

# 创建第二个 y 轴（右边）
ax2 = ax1.twinx()
ax2.plot(px5.timestampAbsH, px5.temperature, 'b--', label='Temperature')
ax2.set_ylabel('Temperature', color='b')
ax2.tick_params(axis='y', labelcolor='b')

# 添加标题
plt.title("The temperature and the PCE of the pixel 5 during the thermal cycling")
# Out:
# Text(0.5, 1.0, 'The temperature and the PCE of the pixel 5 during the thermal cycling')

# %%
fig, ax1 = plt.subplots(figsize=(9, 7), dpi = 300)
ax1.plot(px6.timestampAbsH, px6.PCE, 'r-', label='PCE')
ax1.set_ylabel('PCE', color='r')
ax1.tick_params(axis='y', labelcolor='r')

# 创建第二个 y 轴（右边）
ax2 = ax1.twinx()
ax2.plot(px6.timestampAbsH, px6.temperature, 'b--', label='Temperature')
ax2.set_ylabel('Temperature', color='b')
ax2.tick_params(axis='y', labelcolor='b')

# 添加标题
plt.title("The temperature and the PCE of the pixel 6 during the thermal cycling")
# Out:
# Text(0.5, 1.0, 'The temperature and the PCE of the pixel 6 during the thermal cycling')

# %% [markdown]
# Cycle vs temp:

# %%
for i in range (len(px1.timestamp)):
    print("Time:", px1.timestamp[i], "CycleNum:", px1.cycleNum[i])
# Out:
# Time: 2025-07-28 18:26:29 CycleNum: 22
# Time: 2025-07-28 18:28:30 CycleNum: 397
# Time: 2025-07-28 18:30:30 CycleNum: 299
# Time: 2025-07-28 18:32:30 CycleNum: 55
# Time: 2025-07-28 18:34:29 CycleNum: 394
# Time: 2025-07-28 18:36:29 CycleNum: 155
# Time: 2025-07-28 18:38:29 CycleNum: 7
# Time: 2025-07-28 18:40:29 CycleNum: 294
# Time: 2025-07-28 18:42:29 CycleNum: 238
# Time: 2025-07-28 18:44:29 CycleNum: 345
# Time: 2025-07-28 18:46:30 CycleNum: 4
# Time: 2025-07-28 18:48:30 CycleNum: 288
# Time: 2025-07-28 18:50:30 CycleNum: 146
# Time: 2025-07-28 18:52:29 CycleNum: 165
# Time: 2025-07-28 18:54:29 CycleNum: 300
# Time: 2025-07-28 18:56:29 CycleNum: 50
# Time: 2025-07-28 18:58:29 CycleNum: 150
# Time: 2025-07-28 19:00:29 CycleNum: 335
# Time: 2025-07-28 19:02:30 CycleNum: 64
# Time: 2025-07-28 19:04:30 CycleNum: 340
# Time: 2025-07-28 19:06:30 CycleNum: 232
# Time: 2025-07-28 19:08:29 CycleNum: 143
# Time: 2025-07-28 19:10:29 CycleNum: 281
# Time: 2025-07-28 19:12:29 CycleNum: 67
# ...

# %%
#Try to separate the cycles:
rainbow_colors = [
    '#FF0000',  # Red
    '#FF4000',  # Red-Orange
    '#FF8000',  # Orange
    '#FFBF00',  # Yellow-Orange
    '#FFFF00',  # Yellow
    '#BFFF00',  # Yellow-Green
    '#80FF00',  # Green-Yellow
    '#40FF00',  # Lime Green
    '#00FF00',  # Green
    '#00FF40',  # Green-Cyan
    '#00FF80',  # Spring Green
    '#00FFBF',  # Aqua
    '#00FFFF',  # Cyan
    '#00BFFF',  # Deep Sky Blue
    '#0080FF',  # Dodger Blue
    '#0040FF',  # Royal Blue
    '#0000FF',  # Blue
    '#4000FF',  # Indigo
    '#8000FF',  # Violet
    '#BF00FF',  # Magenta
    '#BF00FF'
]

plt.figure(figsize = (5,3), dpi = 300)
cycleNum = np.array(px5.cycleNum)
temperature = np.array(px5.temperature)
PCE = np.array(px5.PCE)
for i in range(1, 21):
    #print(pxanalyzer.cycleNum)
    mask = (cycleNum == i)
    #print(mask)
    tempM = temperature[mask]
    PCEM = PCE[mask]
    #print(tempM)
    plt.scatter(tempM, PCEM, s = 2, color = rainbow_colors[i])    
#plt.xlim(50,)
#plt.ylim(60,)
plt.grid()
