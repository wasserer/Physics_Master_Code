# %%
import numpy as np
import matplotlib.pyplot as plt
from plot_module.xrd_analyzer import XRDAnalyzer

# %%
folderPath = ""  # Enter your file path/folder path in this place

# %%
analyzer = XRDAnalyzer()
analyzer.import_xrd_folder(folderPath=folderPath)

# %%
analyzer.angles
# Out:
# array([[ 5.  ,  5.02,  5.04, ..., 39.96, 39.98, 40.  ],
#        [ 5.  ,  5.02,  5.04, ..., 39.96, 39.98, 40.  ]])

# %%
plt.figure(figsize=(7, 5), dpi = 300)
for i in range (len(analyzer.label)):
    plt.plot(analyzer.angles[i], analyzer.intensities[i], label = analyzer.label[i])
plt.legend()

# %%
plt.figure()
plt.plot(analyzer.angles[0], analyzer.intensities[0])
