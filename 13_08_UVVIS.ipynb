# %%
import numpy as np
import matplotlib.pyplot as plt
from plot_module.UVVIS_analyzer import UV_VIS_Analyzer

# %%
folderPath = '/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/UV-VIS/VIS13082025/Data'

# %%
analyzer = UV_VIS_Analyzer(folderPath=folderPath)
analyzer.fit()
# Out:
# P3o.Sample.Raw x [[1.55974843]
#  [1.56962025]
#  [1.57961783]
#  [1.58974359]] y [[0.84034752]
#  [1.27466135]
#  [1.73586244]
#  [2.15591859]]
# P30s.Sample.Raw x [[1.55974843]
#  [1.56962025]
#  [1.57961783]
#  [1.58974359]] y [[0.7062988 ]
#  [1.10730908]
#  [1.54947313]
#  [1.95728049]]
# P35s.Sample.Raw x [[1.55974843]
#  [1.56962025]
#  [1.57961783]
#  [1.58974359]] y [[0.75715715]
#  [1.19354176]
#  [1.67103858]
#  [2.11153761]]
# P40s.Sample.Raw x [[1.55974843]
#  [1.56962025]
#  [1.57961783]
#  [1.58974359]] y [[0.82479781]
#  [1.28194804]
#  [1.78864939]
#  [2.25975702]]

# %%
figcolor = ["#0072BD", "#D95319", "#EDB120", "#7E2F8E", "#77AC30", "#4DBEEE", "#A2142F"]
analyzer.UV_multiPlot(figColor=figcolor)

# %%
analyzer.tau_Plot(fit=True, figColor=figcolor)
# Out:
# Fitting right now!
# Fitting right now!
# Fitting right now!
# Fitting right now!
