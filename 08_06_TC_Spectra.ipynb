# %% [markdown]
# # Temp Script

# %%
import numpy as np
from plot_module.Spectra import Spectroscopy
from plot_module.tc_analyzer import ThermalCycling

# %% [markdown]
# ## Toolbox(Do not require later)

# %%
folderPath = '/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/06082025/Thermal_Cycling_2025-08-05_14-59-47'

# %%
sort = ThermalCycling(folderPath=folderPath)
sort.sortData()

# %% [markdown]
# ## Real starting position:

# %%
spectraFolder = '/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/06082025/Thermal_Cycling_2025-08-05_14-59-47/Spectra'

# %% [markdown]
# Old one:

# %%
spectra = Spectroscopy(folderPath=spectraFolder)
spectra.importDark(darkFilePath='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/06082025/Thermal_Cycling_2025-08-05_14-59-47/Spectra/Dark/20250805_150250_Thermal_Cycling_Spectrum_dark_Dark.dat')
spectra.importLight()
spectra.importData()
spectra.interpolate_masked()
spectra.average_value()
spectra.taucCalc()
# Out:
# Debug: 20250806_184930_Thermal_Cycling_Spectrum_Light_c833-2.dat
# Debug: 20250805_151330_Thermal_Cycling_Spectrum_Light_c005-2.dat
# Debug: 20250806_124930_Thermal_Cycling_Spectrum_Light_c653-2.dat
# Debug: 20250805_152723_Thermal_Cycling_Spectrum_Light_c012-1.dat
# Debug: 20250806_044936_Thermal_Cycling_Spectrum_Light_c413-3.dat
# Debug: 20250806_112130_Thermal_Cycling_Spectrum_Light_c609-2.dat
# Debug: 20250806_092924_Thermal_Cycling_Spectrum_Light_c553-1.dat
# Debug: 20250806_162129_Thermal_Cycling_Spectrum_Light_c759-2.dat
# Debug: 20250806_081336_Thermal_Cycling_Spectrum_Light_c515-3.dat
# Debug: 20250806_175336_Thermal_Cycling_Spectrum_Light_c805-3.dat
# Debug: 20250805_213136_Thermal_Cycling_Spectrum_Light_c194-3.dat
# Debug: 20250806_204336_Thermal_Cycling_Spectrum_Light_c890-3.dat
# Debug: 20250806_044929_Thermal_Cycling_Spectrum_Light_c413-2.dat
# Debug: 20250806_202124_Thermal_Cycling_Spectrum_Light_c879-1.dat
# ...

# %%
import numpy as np
from plot_module.Spectra import Spectroscopy
from plot_module.tc_analyzer import ThermalCycling

spectraFolder = '/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/06082025/Thermal_Cycling_2025-08-05_14-59-47/Spectra'
spectra = Spectroscopy(folderPath=spectraFolder)
spectra.importDark(darkFilePath='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/06082025/Thermal_Cycling_2025-08-05_14-59-47/Spectra/Dark/20250805_150250_Thermal_Cycling_Spectrum_dark_Dark.dat')
spectra.Pipeline(darkFolder='/Users/ruodongyang/Documents/Resilio_Sync/TUM Master Physik/Pervoskite Space(Master)/Data/ThermalCycling/06082025/Thermal_Cycling_2025-08-05_14-59-47/Spectra/Dark/20250805_150250_Thermal_Cycling_Spectrum_dark_Dark.dat')
# Out:
# Debug: 20250806_184930_Thermal_Cycling_Spectrum_Light_c833-2.dat
# Debug: 20250805_151330_Thermal_Cycling_Spectrum_Light_c005-2.dat
# Debug: 20250806_124930_Thermal_Cycling_Spectrum_Light_c653-2.dat
# Debug: 20250805_152723_Thermal_Cycling_Spectrum_Light_c012-1.dat
# Debug: 20250806_044936_Thermal_Cycling_Spectrum_Light_c413-3.dat
# Debug: 20250806_112130_Thermal_Cycling_Spectrum_Light_c609-2.dat
# Debug: 20250806_092924_Thermal_Cycling_Spectrum_Light_c553-1.dat
# Debug: 20250806_162129_Thermal_Cycling_Spectrum_Light_c759-2.dat
# Debug: 20250806_081336_Thermal_Cycling_Spectrum_Light_c515-3.dat
# Debug: 20250806_175336_Thermal_Cycling_Spectrum_Light_c805-3.dat
# Debug: 20250805_213136_Thermal_Cycling_Spectrum_Light_c194-3.dat
# Debug: 20250806_204336_Thermal_Cycling_Spectrum_Light_c890-3.dat
# Debug: 20250806_044929_Thermal_Cycling_Spectrum_Light_c413-2.dat
# Debug: 20250806_202124_Thermal_Cycling_Spectrum_Light_c879-1.dat
# ...

# %%
print(len(spectra.timestampAbsS), len(spectra.fileNameAveraged))
# Out:
# 1597 540

# %%
print(len(spectra.values_interp[1]))
# Out:
# 549000

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.scatter(spectra.timestampAbsHN, spectra.bandGap)
plt.ylim(1.45, 1.5)
plt.xlim(0,1.5)
# Out:
# (0.0, 1.5)

# %%
for i in range (len(spectra.bandGap)):
    if spectra.StatusLabel[i] == False:
        #print(spectra.timestampAbsH[i])
        print(spectra.fileNameRaw[i])
# Out:
# 20250805_151523_Thermal_Cycling_Spectrum_Light_c006-1.dat
# 20250805_170336_Thermal_Cycling_Spectrum_Light_c060-3.dat
# 20250805_193923_Thermal_Cycling_Spectrum_Light_c138-1.dat
# 20250805_214924_Thermal_Cycling_Spectrum_Light_c203-1.dat
# 20250806_005136_Thermal_Cycling_Spectrum_Light_c294-3.dat
# 20250806_010336_Thermal_Cycling_Spectrum_Light_c300-3.dat
# 20250806_014523_Thermal_Cycling_Spectrum_Light_c321-1.dat
# 20250806_015336_Thermal_Cycling_Spectrum_Light_c325-3.dat
# 20250806_062136_Thermal_Cycling_Spectrum_Light_c459-3.dat
# 20250806_070129_Thermal_Cycling_Spectrum_Light_c479-2.dat
# 20250806_095123_Thermal_Cycling_Spectrum_Light_c564-1.dat
# 20250806_111330_Thermal_Cycling_Spectrum_Light_c605-2.dat
# 20250806_112536_Thermal_Cycling_Spectrum_Light_c611-3.dat
# 20250806_112924_Thermal_Cycling_Spectrum_Light_c613-1.dat
# 20250806_124936_Thermal_Cycling_Spectrum_Light_c653-3.dat
# 20250806_125536_Thermal_Cycling_Spectrum_Light_c656-3.dat
# ...

# %% [markdown]
# bandGap = [],
# Values: [[], [], []]

# %%
#num = 1471
for num in range (390, 400):
    plt.figure()
    plt.plot(spectra.eV, spectra.valueTaucs[num], label='Tauc Plot at temperature {:.1f} Degree'.format(spectra.temperatures[num]))
    plt.plot(spectra.eV, spectra.tauc_slope_b[num] + spectra.tauc_slope[num] * spectra.eV, label=r'Fit Line, band gap = {:.3f} eV'.format(spectra.bandGap[num]))
    plt.xlim(1.45, 2)
    plt.ylim(0,2)
    plt.xlabel('Energy (eV)')
    plt.ylabel('Tauc Plot (Absorbance * photon energy)^0.5')
    plt.title('Tauc Plot for Band Gap Calculation')
    plt.legend()
    plt.grid()
